# %% [markdown]
# <a href="https://colab.research.google.com/github/ChintzRuparel/Stock-Market-Prediction-Using-LSTM/blob/main/NIFTY100_Historical.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

plt.rcParams['figure.figsize'] = (20.0, 10.0)

# %% [markdown]
# ### data set reading

# %%
df = pd.read_csv('NIFTY_100.csv') ##Source File to be changed here
df.head()
# Out:
#         Date  Last/Close  Open  High  Low
# 0  01/1/2003     1000.00   0.0   0.0  0.0
# 1  02/1/2003     1008.03   0.0   0.0  0.0
# 2  03/1/2003     1004.49   0.0   0.0  0.0
# 3  06/1/2003      999.85   0.0   0.0  0.0
# 4  07/1/2003      997.81   0.0   0.0  0.0

# %% [markdown]
# ### preprocessing data set to perform analysis

# %%
df.shape
# Out:
# (4603, 5)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4603 entries, 0 to 4602
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Date        4603 non-null   object
#  1   Last/Close  4603 non-null   float64
#  2   Open        4603 non-null   float64
#  3   High        4603 non-null   float64
#  4   Low         4603 non-null   float64
# dtypes: float64(4), object(1)
# memory usage: 179.9+ KB

# %%
df1 = df.iloc[:,1]
df1.head()
# Out:
# 0    1000.00
# 1    1008.03
# 2    1004.49
# 3     999.85
# 4     997.81
# Name: Last/Close, dtype: float64

# %%
df1.tail()
# Out:
# 4598    15928.1
# 4599    15957.1
# 4600    16066.9
# 4601    16054.9
# 4602    16117.4
# Name: Last/Close, dtype: float64

# %%
df1 = df1.replace('[\$,]', '', regex=True).astype(float)
df1.head()
# Out:
# 0    1000.00
# 1    1008.03
# 2    1004.49
# 3     999.85
# 4     997.81
# Name: Last/Close, dtype: float64

# %%
plt.plot(df1)
plt.xlabel("data-point ie time")
plt.ylabel("stock price")
# Out:
# Text(0, 0.5, 'stock price')

# %%
#show the components of this time series
from statsmodels.tsa.seasonal import seasonal_decompose

result  = seasonal_decompose(pd.Series(df1),period=100)

result.plot()
plt.title('Apple Stock')
plt.show()

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range = (0,1))

# %%
df1.shape
# Out:
# (4603,)

# %%
df1 = scaler.fit_transform(np.array(df1).reshape(-1,1))

# %%
print(df1)
print('\n df1 present shape : ', df1.shape)
# Out:
# [[0.00895996]
#  [0.00948571]
#  [0.00925394]
#  ...
#  [0.99543327]
#  [0.99464759]
#  [0.99873965]]
#
#  df1 present shape :  (4603, 1)

# %% [markdown]
# ### splitting data (70/30)

# %%
training_size = int(len(df1)*0.7)
test_size = len(df1) - training_size
print('Training Size : ',training_size)
print('Test Size : ',test_size)
# Out:
# Training Size :  3222
# Test Size :  1381

# %%
train_data, test_data = df1[0:training_size,:],df1[training_size:len(df1),:]
print('Training Data Shape : ', train_data.shape)
print('Test Data Shape: ', test_data.shape)
# Out:
# Training Data Shape :  (3222, 1)
# Test Data Shape:  (1381, 1)

# %% [markdown]
# ### | windowing data set |

# %%
def create_dataset(dataset, window=1):
    dataX, dataY= [], []
    for i in range(len(dataset)-window-1):
        a = dataset[i:(i+window),0]
        dataX.append(a)
        dataY.append(dataset[i+window,0])
    return np.array(dataX), np.array(dataY)

# %%
window = 100
X_train, y_train = create_dataset(train_data, window=100)
X_test, y_test = create_dataset(test_data, window=100)

# %%
print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# (3121, 100) (3121,)
# (1280, 100) (1280,)

# %%
X_train = X_train.reshape(X_train.shape[0],X_train.shape[1],1)
X_test = X_test.reshape(X_test.shape[0],X_test.shape[1],1)

# %% [markdown]
# ### lstm coding

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM

# %%
model = Sequential()
model.add(LSTM(50, return_sequences = True, input_shape = (100,1)))
model.add(LSTM(50, return_sequences = True))
model.add(LSTM(50))
model.add(Dense(1))

model.compile(loss='mean_squared_error', optimizer = 'adam')

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 100, 50)           10400
#
#  lstm_1 (LSTM)               (None, 100, 50)           20200
#
#  lstm_2 (LSTM)               (None, 50)                20200
#
#  dense (Dense)               (None, 1)                 51
#
# =================================================================
# Total params: 50,851
# Trainable params: 50,851
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### fitting data to model

# %%
model.fit(X_train,y_train,validation_data = (X_test,y_test), epochs = 2, batch_size=64,verbose=1)
# Out:
# Epoch 1/2
# 49/49 [==============================] - 17s 227ms/step - loss: 0.0052 - val_loss: 0.0010
# Epoch 2/2
# 49/49 [==============================] - 10s 199ms/step - loss: 2.0933e-04 - val_loss: 0.0021

# %%
y_pred = scaler.inverse_transform(model.predict(X_test))
# Out:
# 40/40 [==============================] - 3s 38ms/step

# %%
y_test = scaler.inverse_transform(y_test.reshape(-1, 1))

# %%
y_pred[:5]
# Out:
# array([[7842.7017],
#        [7846.985 ],
#        [7850.6143],
#        [7853.9253],
#        [7857.471 ]], dtype=float32)

# %%
y_test[:5]
# Out:
# array([[7982.8 ],
#        [8001.95],
#        [7969.55],
#        [8026.4 ],
#        [7941.5 ]])

# %% [markdown]
# ### evaluation

# %%
import math
from sklearn.metrics import mean_squared_error

rmse_score = math.sqrt(mean_squared_error(y_test,y_pred))
print('Root Mean Squared Error(test) : ',rmse_score)
# Out:
# Root Mean Squared Error(test) :  703.486808508962

# %%
from sklearn.metrics import r2_score
print('R-squared Score  : ',r2_score(y_test,y_pred))
# Out:
# R-squared Score  :  0.849056590876419

# %% [markdown]
# ### visualization + plotting

# %%
# shift train predictions for plotting
train_predict = scaler.inverse_transform(model.predict(X_train))

look_back=100
trainPredictPlot = np.empty_like(df1)
trainPredictPlot[:, :] = np.nan
trainPredictPlot[look_back:len(train_predict)+look_back, :] = train_predict
# shift test predictions for plotting
testPredictPlot = np.empty_like(df1)
testPredictPlot[:, :] = np.nan
testPredictPlot[len(train_predict)+(look_back*2)+1:len(df1)-1, :] = y_pred
# plot baseline and predictions
plt.plot(scaler.inverse_transform(df1))
plt.plot(trainPredictPlot)
plt.plot(testPredictPlot)
plt.legend()
plt.show()
# Out:
# 98/98 [==============================] - 5s 37ms/step
# WARNING:matplotlib.legend:No handles with labels found to put in legend.

# %% [markdown]
# ### predicting 30 Days future value

# %%
x_input=test_data[len(test_data)-100:].reshape(1,-1)
x_input.shape
# Out:
# (1, 100)

# %%
temp_input=list(x_input)
temp_input=temp_input[0].tolist()

# %%
# demonstrate prediction for next 30 days
from numpy import array

lst_output=[]
n_steps=100
i=0
while(i<30):
    
    if(len(temp_input)>100):
        #print(temp_input)
        x_input=np.array(temp_input[1:])
        #print("{} day input {}".format(i,x_input))
        x_input=x_input.reshape(1,-1)
        x_input = x_input.reshape((1, n_steps, 1))
        #print(x_input)
        yhat = model.predict(x_input, verbose=0)
        #print("{} day output {}".format(i,yhat))
        temp_input.extend(yhat[0].tolist())
        temp_input=temp_input[1:]
        #print(temp_input)
        lst_output.extend(yhat.tolist())
        i=i+1
    else:
        x_input = x_input.reshape((1, n_steps,1))
        yhat = model.predict(x_input, verbose=0)
        #print(yhat[0])
        temp_input.extend(yhat[0].tolist())
        #print(len(temp_input))
        lst_output.extend(yhat.tolist())
        i=i+1
    

#print(lst_output)

# %%
day_new=np.arange(1,101)
day_pred=np.arange(101,131)

# %%
print(scaler.inverse_transform(lst_output))
# Out:
# [[14426.94038116]
#  [14422.24832624]
#  [14405.50841432]
#  [14375.92407032]
#  [14334.33556717]
#  [14282.42800259]
#  [14222.24242958]
#  [14155.8080663 ]
#  [14084.97387736]
#  [14011.30388107]
#  [13936.07897019]
#  [13860.2686904 ]
#  [13784.61499452]
#  [13709.63861507]
#  [13635.69550731]
#  [13563.017816  ]
#  [13491.73754501]
#  [13421.92843443]
#  [13353.60960206]
#  [13286.76466122]
#  [13221.37267336]
#  [13157.38447841]
#  [13094.76275116]
#  [13033.45195892]
#  [12973.40567275]
#  [12914.58019482]
#  [12856.92454433]
#  [12800.4023064 ]
#  [12744.9734247 ]
#  [12690.60057398]]

# %%
plt.plot(day_new,scaler.inverse_transform(df1[len(df1)-100:]))
plt.plot(day_pred,scaler.inverse_transform(lst_output))
